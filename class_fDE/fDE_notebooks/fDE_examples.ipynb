# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from classy_fDE import Class
#import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
from scipy.optimize import minimize, brentq, curve_fit
from scipy.integrate import cumtrapz
from scipy.interpolate import interp1d
from matplotlib.gridspec import GridSpec
from matplotlib.ticker import AutoMinorLocator, LogLocator, NullFormatter
from matplotlib.patches import Patch
import scienceplots
#import seaborn as sns
import matplotlib as mpl
from matplotlib import cm
from matplotlib.colors import Normalize, ListedColormap
import matplotlib.colors as mcolors
import camb
from camb import initialpower, model

plt.style.use('mine.mplstyle')
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "text.latex.preamble": r"\usepackage{amssymb}"
})

# %%
# Define parameters as a dictionary
params = {
    'output': '',
    # Cosmological parameters
    'h': 0.6821,
    #'theta_s_100': 1.04178,
    'A_s': 2.216e-9,
    'n_s': 0.9686,
    'omega_b': 0.02253,
    'omega_cdm': 0.1177,
    'tau_reio': 0.085,
    # Neutrinos and relativistic species
    'N_ncdm': 1,
    'N_ur': 2.0328,
    'm_ncdm': 0.06,
    'Omega_Lambda': 0,
    'fluid_equation_of_state': 'faDE'
}

# %% [markdown]
# ## 1.1 Example with $f_{\rm DE}(a)=1+f_a\left(1-a\right)$

# %%
faV=-2
M=Class()
M.set(params)
M.set({'fa_fld':faV})
M.compute()
print("h=",np.round(M.h(),4))
# Out:
# h= 0.6821

# %%
baM = M.get_background()
rhoDE=baM['(.)rho_fld']
fDE=rhoDE/rhoDE[-1]
wDE=baM['(.)w_fld']
z=baM['z']

# %%
plt.plot(z,fDE,c='tab:blue',lw=1.2)
#plt.plot(z,wDE,c='tab:purple',lw=1.2)
plt.plot(z, 1+faV*z/(1+z),ls='--',lw=1.2,c='tab:red')
plt.xlim(0,4)
plt.xlabel(r'Redshift $z$')
plt.ylabel(r'$f_{\rm DE}(z)$')
plt.show()

# %% [markdown]
# ## 1.2 Example with $f_{\rm DE}(a)=1+f_a\left(1-a\right)+f_b\left(1-a\right)^2$

# %%
faV=1
fbV=-2
M=Class()
M.set(params)
M.set({'fluid_equation_of_state': 'faDE_2','fa_fld':faV, 'dfa_fld':fbV})
M.compute()
print("h=",np.round(M.h(),4))
# Out:
# h= 0.6821

# %%
baM = M.get_background()
rhoDE=baM['(.)rho_fld']
fDE=rhoDE/rhoDE[-1]
wDE=baM['(.)w_fld']
z=baM['z']

# %%
plt.plot(z,fDE,c='tab:blue',lw=1.2)
#plt.plot(z,wDE,c='tab:purple',lw=1.2)
plt.plot(z, 1+faV*z/(1+z)+fbV*(z/(1+z))**2,ls='--',lw=1.2,c='tab:red')
plt.xlim(0,4)
plt.xlabel(r'Redshift $z$')
plt.ylabel(r'$f_{\rm DE}(z)$')
plt.show()

# %% [markdown]
# ## 2.1 Example with $f_{\rm DE}(a)=1+\left(f_{\rm pv}-1 \right)\frac{1-a}{1-a_{\rm pv}}$

# %%
def from_fp_ap_to_fa(fp,ap):
    return (fp-1)/(1-ap)
def from_fa_ap_to_fp(fa,ap):
    return 1+fa*(1-ap)
fpv=3
apv=2/3
fav=from_fp_ap_to_fa(fpv,apv)
M2=Class()
M2.set(params)
#M2.set({'fa_fld':fav})
M2.set({'fp_fld':fpv,'ap_fld':apv,'fluid_equation_of_state': 'fpDE'})
       #'input_verbose': 10, 'background_verbose': 10,'perturbations_verbose': 1,})
M2.compute()
print("h=",np.round(M2.h(),4))
# Out:
# h= 0.6821

# %%
baM2 = M2.get_background()
rhoDE_v2=baM2['(.)rho_fld']
fDE_v2=rhoDE_v2/rhoDE_v2[-1]
wDE_v2=baM2['(.)w_fld']
z_v2=baM2['z']

# %%
plt.plot(z_v2,fDE_v2,zorder=1,lw=1.2,c='tab:blue')
plt.plot(z_v2, 1+fav*z_v2/(1+z_v2),ls='--',zorder=1,lw=1.2,c='tab:red')
plt.scatter(1/apv-1,fpv, marker='d',color='k', s=8,zorder=2)
plt.xlim(0,10)
plt.xlabel(r'Redshift $z$')
plt.ylabel(r'$f_{\rm DE}(z)$')
plt.show()

# %% [markdown]
# ## 2.2 Example with $f_{\rm DE}(a)$ in terms of $f_{\rm pv}=f_{\rm DE}(a_{\rm pv})$ and $w_{\rm pv}=w_{\rm DE}(a_{\rm pv})$

# %%
fpv=1.5
wpv=-.5
apv=2/3
M2=Class()
M2.set(params)
#M2.set({'fa_fld':fav})
M2.set({'fp_fld':fpv,'ap_fld':apv,'fluid_equation_of_state': 'fpDE_2','wp_fld':wpv})
       #'input_verbose': 10, 'background_verbose': 10,'perturbations_verbose': 1,})
M2.compute()
print("h=",np.round(M2.h(),4))
# Out:
# h= 0.6821

# %%
baM2 = M2.get_background()
rhoDE_v2=baM2['(.)rho_fld']
fDE_v2=rhoDE_v2/rhoDE_v2[-1]
wDE_v2=baM2['(.)w_fld']
z_v2=baM2['z']

# %%
def f_DE2(z, Fp, wp, ap):
    a=1/(1+z)
    """
    Dark energy density fraction f_DE(a) = rho_DE(a)/rho_DE(0)
    in the (Fp, wp, ap) parameterization.
    
    f_DE(a) = Fp - 3(1+wp)*Fp/ap * (a - ap) + fb * (a - ap)^2
    with fb fixed by f_DE(1) = 1.
    """
    fb = (1 - Fp + 3*(1+wp)*Fp/ap * (1 - ap)) / (1 - ap)**2
    return Fp - 3*(1+wp)*Fp/ap * (a - ap) + fb * (a - ap)**2


def w_DE2(z, Fp, wp, ap):
    a=1/(1+z)
    """
    Dark energy equation of state w(a) from
    d ln f_DE / d ln a = -3(1 + w(a))
    """
    fDE = f_DE2(z, Fp, wp, ap)
    fb = (1 - Fp + 3*(1+wp)*Fp/ap * (1 - ap)) / (1 - ap)**2
    dfDE_da = -3*(1+wp)*Fp/ap + 2*fb*(a - ap)
    return -1 - a * dfDE_da / (3 * fDE)

# %%
plt.plot(z_v2,fDE_v2,zorder=1,lw=1.2,c='tab:blue',label=r'$f_{\rm DE}(a)$')
plt.plot(z_v2,f_DE2(z_v2,fpv,wpv,apv),zorder=1,lw=1,ls='--',c='k')
plt.plot(z_v2,wDE_v2,zorder=1,lw=1.2,c='tab:red',label=r'$w_{\rm DE}(a)$')
plt.plot(z_v2,w_DE2(z_v2,fpv,wpv,apv),zorder=1,ls='--',c='k',lw=1,label=r'analytic check')
plt.scatter(1/apv-1,fpv, marker='d',color='k', s=8,zorder=2)
plt.scatter(1/apv-1,wpv, marker='d',color='k', s=8,zorder=2)
plt.xlim(0,10)
plt.ylim(-3,3)
plt.legend()
plt.xlabel(r'Redshift $z$')
plt.show()

# %% [markdown]
# ## 3. Example with $w_0$ and $w_0+w_a$

# %%
w0V=-0.5
waV=-1.5
M3=Class()
M3.set(params)
M3.set({'w0_fld':w0V,'w0wa_fld':waV+w0V,'fluid_equation_of_state': 'CLP'})
M3.compute()
print("h=",np.round(M3.h(),4))
# Out:
# h= 0.6821

# %%
baM3 = M3.get_background()
wDE_v3=baM3['(.)w_fld']
z_v3=baM3['z']

# %%
plt.plot(z_v3,wDE_v3,zorder=1,lw=1.2,c='tab:blue')
plt.plot(z_v3, w0V+waV*z_v3/(1+z_v3),ls='--',zorder=1,lw=1.2,c='tab:red')
plt.xlim(0,10)
plt.xlabel(r'Redshift $z$')
plt.ylabel(r'$w_{\rm DE}(z)$')
plt.show()

# %% [markdown]
# ## 4. From $(w_0,\,w_a)$ to $(w_p,\,f_p)$

# %%
def fpwp_from_w0wa(w0,wa,zp=0.5):
    fp =(1 + zp)**(3*(1+w0+wa))*np.exp(-3*wa*zp/(1 + zp))
    wp=w0+wa*zp/(1+zp)
    return wp,fp
def w0wa_from_fpwp(wp, fp, zp=0.5):
    zp_fac = zp/(1+zp)
    L = np.log1p(zp)
    detA = 3*L*zp_fac - 3*(L - zp_fac)
    with np.errstate(divide='ignore', invalid='ignore'):
        chip = np.log(fp/(1+zp)**3)
    w0 = (zp_fac*chip - 3*(L - zp_fac)*wp)/detA
    wa = (3*L*wp - chip)/detA
    return w0, wa

# %%
wpV,fpV=fpwp_from_w0wa(w0V,waV)
M4=Class()
M4.set(params)
M4.set({'wp_fld':wpV,'fp_fld':fpV,'fluid_equation_of_state': 'CLP'})
M4.compute()
print("h=",np.round(M4.h(),4))
# Out:
# h= 0.6821

# %%
plt.plot(z_v4,wDE_v4,zorder=1,lw=1.2,c='tab:blue')
plt.plot(z_v4, w0V+waV*z_v4/(1+z_v4),ls='--',zorder=1,lw=1.2,c='tab:red')
plt.xlim(0,10)
plt.xlabel(r'Redshift $z$')
plt.ylabel(r'$w_{\rm DE}(z)$')
plt.show()

# %%
baM4 = M4.get_background()
wDE_v4=baM4['(.)w_fld']
z_v4=baM4['z']

# %%
def fpwp_from_w0wa(w0,wa,zp=0.5):
    fp =(1 + zp)**(3*(1+w0+wa))*np.exp(-3*wa*zp/(1 + zp))
    wp=w0+wa*zp/(1+zp)
    return wp,fp
n_samples=150_000
w0_min,w0_max= -3., 1.
wa_min, wa_max= -3.,2.
w0_samples=np.random.uniform(w0_min,w0_max,size=n_samples)
wa_samples=np.random.uniform(wa_min,wa_max,size=n_samples)
w0wa_samples=np.vstack([w0_samples,wa_samples]).T
wpfp_samples = np.column_stack(fpwp_from_w0wa(*w0wa_samples.T))
bins=int(np.sqrt(n_samples))
cw0, ew0=np.histogram(w0_samples, bins=bins)
cwa, ewa=np.histogram(wa_samples, bins=bins)
cwp, ewp=np.histogram(wpfp_samples[:,0], bins=bins)
cfp, efp=np.histogram(wpfp_samples[:,1], bins=bins)
cw0_norm=cw0/cw0.max()
cw0_center=(ew0[:-1]+ew0[1:])/2
cwa_norm=cwa/cwa.max()
cwa_center=(ewa[:-1]+ewa[1:])/2
cwp_norm=cwp/cwp.max()
cwp_center=(ewp[:-1]+ewp[1:])/2
cfp_norm=cfp/cfp.max()
cfp_center=(efp[:-1]+efp[1:])/2

# %%
fig1=plt.figure(figsize=(7.9, 7.9/1.61803398875*0.9))
#gs1 = GridSpec(44,46,figure=fig1)
gs1 = GridSpec(44,92,figure=fig1)

ax2 = fig1.add_subplot(gs1[:19,:28])
ax1 = fig1.add_subplot(gs1[25:,:28])
ax3 = fig1.add_subplot(gs1[:22,36:64])
ax4 = fig1.add_subplot(gs1[22:,64:])
ax5=fig1.add_subplot(gs1[22:,36:64])
#ax52=fig1.add_subplot(gs1[23:32,52:63])
# --- Plot w0 1D prior ---
ax1.bar(cw0_center,cw0_norm,width=ew0[1]-ew0[0],color='lightcoral')
ax1.plot(cw0_center,cw0_norm,color='tab:red',ls='-',lw=.7)
ax1.set_xlim(-3,1)
ax1.set_xticks([-3,-2,-1,0,1])
ax1.set_xticklabels([-3.0,-2.0,-1.0,0.0,1.0])
ax1.set_xlabel(r"$w_0$",labelpad=0)
ax1.set_ylim(.0,1.05)
ax1.set_yticks([0.0,0.5,1])
ax1.set_ylabel(r'$\mathcal{P}\left(w_0\right)$')

# --- Plot wa 1D prior ---
ax2.bar(cwa_center,cwa_norm,width=ewa[1]-ewa[0],color='lightcoral')
ax2.plot(cwa_center,cwa_norm,color='tab:red',ls='-',lw=.7)
ax2.set_xlim(-3,2)
ax2.set_xticks([-3,-2,-1,0,1,2])
ax2.set_xticklabels([-3.0,-2.0,-1.0,0.0,1.0, 2.0])
ax2.set_xlabel(r"$w_a$",labelpad=0)
ax2.set_ylim(0,1.05)
ax2.set_yticks([0.0,0.5,1])
ax2.set_ylabel(r'$\mathcal{P}\left(w_a\right)$')

ax3.bar(cwp_center,cwp_norm,width=ewp[1]-ewp[0],color='lightcoral')
ax3.plot(cwp_center,cwp_norm,color='tab:red',ls='-',lw=.7)
ax3.set_xlim(-4.1,1.9)
ax3.set_xticks([-4,-3,-2,-1,0,1])
ax3.set_xticklabels([])
ax3.set_xlabel(r"$w_p$",labelpad=0)
ax3.set_ylim(-.025,1.05)
ax3.set_yticks([0.0,0.5,1])
#ax3.set_ylabel(r'$\mathcal{P}\left(w_a\right)$')
ax3.yaxis.set_label_position('right')
ax3.tick_params(axis='y',which='both', labelright=True,labelleft=False)

ax4.bar(cfp_center,cfp_norm,width=efp[1]-efp[0],color='lightcoral')
ax4.plot(cfp_center,cfp_norm,color='tab:red',ls='-',lw=.7)

ax4.set_xlabel(r'$f_p$')
ax4.set_ylim(-.025,1.05)
ax4.set_yticks([0.,0.5,1])

# Move y-label and ticks to right side for cleaner panels
ax4.yaxis.set_label_position('right')
ax4.tick_params(axis='y',which='both', labelright=True,labelleft=False)

# Annotate arrow showing mapping direction
plt.annotate(
    '', xy=(0.33, 0.465), xytext=(0.30, 0.465),
    xycoords='figure fraction', textcoords='figure fraction',
    arrowprops=dict(
        arrowstyle='->',          # slightly more stylized arrow
        lw=1.0,                    # match likely thinner lines from style
        color='black',             # default axis/line color in style
        shrinkA=0, shrinkB=0,
        mutation_scale=7          # controls arrowhead size
    )
)
"""
ax4.set_xlim(-0.5,19)
ax4.set_xticks([0,5,10,15])
ax4.set_xticklabels([0,5,10,15])
ax5.set_ylim(-0.5,19)
ax5.set_yticks([0,5,10,15])
ax5.set_yticklabels([0,5,10,15])
"""
ax4.set_xlim(-0.1,3)
ax4.set_xticks([0,1,2,3])
ax4.set_xticklabels([0,1,2,3])
ax5.set_ylim(-0.1,3)
ax5.set_yticks([0,1,2,3])
ax5.set_yticklabels([0,1,2,3])
ax5.set_xlim(-4.1,1.9)
ax5.set_xticks([-4,-3,-2,-1,0,1])
ax5.set_xticklabels([-4.0,-3.0,-2.0,-1.0,0.0,1.0])

ax5.set_xlabel(r'$w_p$')
ax5.set_ylabel(r'$f_p$')

# --- Prepare 2D histograms for w0-wa contours ---

#make color lighter than lightcoral
c1 = np.array(mcolors.to_rgb('lightcoral'))
lighten_factor = 0.5
c2 = c1 + (1 - c1) * lighten_factor

# Base histogram for Training Samples
counts, xedges, yedges = np.histogram2d(
    wpfp_samples[:,0], wpfp_samples[:,1],
    bins=[bins, bins]
)
X = 0.5*(xedges[:-1] + xedges[1:])
Y = 0.5*(yedges[:-1] + yedges[1:])
X, Y = np.meshgrid(X, Y)

# define probability‐threshold fractions for each contour
pth_99 = 0.003
pth_95 = 0.05
pth_68 = 0.32
thr_99 = counts.max() * pth_99
thr_95 = counts.max() * pth_95
thr_68 = counts.max() * pth_68
# boolean masks for each region
mask_99 = counts >= thr_99
mask_95 = counts >= thr_95
mask_68 = counts >= thr_68
mask = counts >= 0.0001 #fake mask to show all training samples

# --- Plot filled contour regions in ax5 ---
ax5.contourf(X, Y, mask.T.astype(float),levels=[0.5, 1.0], colors=[c2],zorder=2,)
ax5.contourf(X, Y, mask_99.T.astype(float),levels=[0.5, 1.0], colors=[c1],zorder=2.1,)
ax5.contourf(X, Y, mask_95.T.astype(float),levels=[0.5, 1.0], colors=['tab:red'],zorder=2.1,)
ax5.contourf(X, Y, mask_68.T.astype(float),levels=[0.5, 1.0], colors=['darkred'],zorder=2.1,)



#Create Legend:
patch99 = Patch(facecolor=c1)
patch95 = Patch(facecolor='tab:red')
patch68 = Patch(facecolor='darkred')
handles, labels = ax2.get_legend_handles_labels()
handles += [(patch68, patch95, patch99)]
labels  += [r"$68\%,95\%,99\%$  C.L."]
ax2.legend(
    handles=handles,
    labels=labels,
    loc=(2.5, .5),
    handler_map={tuple: mpl.legend_handler.HandlerTuple(ndivide=None, pad=0.0)},
    frameon=False
)


plt.tight_layout()
plt.subplots_adjust(wspace=0.0, hspace=0.0)
#plt.savefig("figs/fig_1_v0.png")
#plt.savefig("figs/fig_1_v0.pdf")
plt.show()
# Out:
# /var/folders/fv/1zh_rtgn403_j1sl_9fqmp9m0000gs/T/ipykernel_92495/4122910759.py:142: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()

# %%
def w0wa_from_fpwp(wp, fp, zp=0.5):
    zp_fac = zp/(1+zp)
    L = np.log1p(zp)
    detA = 3*L*zp_fac - 3*(L - zp_fac)
    with np.errstate(divide='ignore', invalid='ignore'):
        chip = np.log(fp/(1+zp)**3)
    w0 = (zp_fac*chip - 3*(L - zp_fac)*wp)/detA
    wa = (3*L*wp - chip)/detA
    return w0, wa

n_samples = 150_000
wp_min, wp_max = -3., 1.
fp_min, fp_max = -1., 3.
wp_samples = np.random.uniform(wp_min, wp_max, size=n_samples)
fp_samples = np.random.uniform(fp_min, fp_max, size=n_samples)
wpfp_samples = np.vstack([wp_samples, fp_samples]).T
w0wa_samples = np.column_stack(w0wa_from_fpwp(*wpfp_samples.T))

good = np.isfinite(w0wa_samples).all(axis=1)
w0wa_samples = w0wa_samples[good]
wpfp_samples = wpfp_samples[good]
wp_samples, fp_samples = wpfp_samples.T

w0_lo, w0_hi = -8.5, 3.5
wa_lo, wa_hi = -19., 25.

bins = int(np.sqrt(good.sum()))
cwp, ewp = np.histogram(wp_samples, bins=bins, range=(wp_min, wp_max))
cfp, efp = np.histogram(fp_samples, bins=bins, range=(fp_min, fp_max))
cw0, ew0 = np.histogram(w0wa_samples[:, 0], bins=bins, range=(w0_lo, w0_hi))
cwa, ewa = np.histogram(w0wa_samples[:, 1], bins=bins, range=(wa_lo, wa_hi))

cwp_norm = cwp/cwp.max(); cwp_center = (ewp[:-1]+ewp[1:])/2
cfp_norm = cfp/cfp.max(); cfp_center = (efp[:-1]+efp[1:])/2
cw0_norm = cw0/cw0.max(); cw0_center = (ew0[:-1]+ew0[1:])/2
cwa_norm = cwa/cwa.max(); cwa_center = (ewa[:-1]+ewa[1:])/2

# %%
fig1 = plt.figure(figsize=(7.9, 7.9/1.61803398875*0.9))
gs1 = GridSpec(44, 92, figure=fig1)

ax2 = fig1.add_subplot(gs1[:19, :28])
ax1 = fig1.add_subplot(gs1[25:, :28])
ax3 = fig1.add_subplot(gs1[:22, 36:64])
ax4 = fig1.add_subplot(gs1[22:, 64:])
ax5 = fig1.add_subplot(gs1[22:, 36:64])

# --- Plot wp 1D prior ---
ax1.bar(cwp_center, cwp_norm, width=ewp[1]-ewp[0], color='lightcoral')
ax1.plot(cwp_center, cwp_norm, color='tab:red', ls='-', lw=.7)
ax1.set_xlim(-3, 1)
ax1.set_xticks([-3, -2, -1, 0, 1])
ax1.set_xticklabels([-3.0, -2.0, -1.0, 0.0, 1.0])
ax1.set_xlabel(r"$w_p$", labelpad=0)
ax1.set_ylim(.0, 1.05)
ax1.set_yticks([0.0, 0.5, 1])
ax1.set_ylabel(r'$\mathcal{P}\left(w_p\right)$')

# --- Plot fp 1D prior ---
ax2.bar(cfp_center, cfp_norm, width=efp[1]-efp[0], color='lightcoral')
ax2.plot(cfp_center, cfp_norm, color='tab:red', ls='-', lw=.7)
ax2.set_xlim(-1, 3)
ax2.set_xticks([-1, 0, 1, 2, 3])
ax2.set_xticklabels([-1.0, 0.0, 1.0, 2.0, 3.0])
ax2.set_xlabel(r"$f_p$", labelpad=0)
ax2.set_ylim(0, 1.05)
ax2.set_yticks([0.0, 0.5, 1])
ax2.set_ylabel(r'$\mathcal{P}\left(f_p\right)$')

ax3.bar(cw0_center, cw0_norm, width=ew0[1]-ew0[0], color='lightcoral')
ax3.plot(cw0_center, cw0_norm, color='tab:red', ls='-', lw=.7)
"""
ax3.set_xlim(w0_lo, w0_hi)
ax3.set_xticks([-8, -6, -4, -2, 0, 2])
"""
ax3.set_xlim(-3, 1)
ax3.set_xticks([-3,-2,-1,0,1])
ax3.set_xticklabels([])
ax3.set_xlabel(r"$w_0$", labelpad=0)
ax3.set_ylim(-.025, 1.05)
ax3.set_yticks([0.0, 0.5, 1])
ax3.yaxis.set_label_position('right')
ax3.tick_params(axis='y', which='both', labelright=True, labelleft=False)

ax4.bar(cwa_center, cwa_norm, width=ewa[1]-ewa[0], color='lightcoral')
ax4.plot(cwa_center, cwa_norm, color='tab:red', ls='-', lw=.7)
ax4.set_xlabel(r'$w_a$')
"""
ax4.set_xlim(wa_lo, wa_hi)
ax4.set_xticks([-10, 0, 10, 20])
ax4.set_xticklabels([-10, 0, 10, 20])
"""
ax4.set_xlim(-3,2)
ax4.set_xticks([-3, -2, -1, 0,1,2])
ax4.set_xticklabels([-3,-2,-1, 0, 1, 2])
ax4.set_ylim(-.025, 1.05)
ax4.set_yticks([0., 0.5, 1])
ax4.yaxis.set_label_position('right')
ax4.tick_params(axis='y', which='both', labelright=True, labelleft=False)

plt.annotate(
    '', xy=(0.33, 0.465), xytext=(0.30, 0.465),
    xycoords='figure fraction', textcoords='figure fraction',
    arrowprops=dict(arrowstyle='->', lw=1.0, color='black',
                    shrinkA=0, shrinkB=0, mutation_scale=7)
)

ax5.set_ylim(-3,2)
ax5.set_yticks([-3, -2, -1, 0,1,2])
ax5.set_yticklabels([-3,-2,-1, 0, 1, 2])
ax5.set_xlim(-3, 1)
ax5.set_xticks([-3,-2,-1,0,1])
ax5.set_xticklabels([-3,-2,-1,0,1])

ax5.set_xlabel(r'$w_0$')
ax5.set_ylabel(r'$w_a$')

c1 = np.array(mcolors.to_rgb('lightcoral'))
lighten_factor = 0.5
c2 = c1 + (1 - c1) * lighten_factor

counts, xedges, yedges = np.histogram2d(
    w0wa_samples[:, 0], w0wa_samples[:, 1],
    bins=[bins, bins], range=[[w0_lo, w0_hi], [wa_lo, wa_hi]]
)
X = 0.5*(xedges[:-1] + xedges[1:])
Y = 0.5*(yedges[:-1] + yedges[1:])
X, Y = np.meshgrid(X, Y)

pth_99, pth_95, pth_68 = 0.003, 0.05, 0.32
thr_99 = counts.max() * pth_99
thr_95 = counts.max() * pth_95
thr_68 = counts.max() * pth_68
mask_99 = counts >= thr_99
mask_95 = counts >= thr_95
mask_68 = counts >= thr_68
mask = counts >= 0.0001

ax5.contourf(X, Y, mask.T.astype(float), levels=[0.5, 1.0], colors=[c2], zorder=2)
ax5.contourf(X, Y, mask_99.T.astype(float), levels=[0.5, 1.0], colors=[c1], zorder=2.1)
ax5.contourf(X, Y, mask_95.T.astype(float), levels=[0.5, 1.0], colors=['tab:red'], zorder=2.1)
ax5.contourf(X, Y, mask_68.T.astype(float), levels=[0.5, 1.0], colors=['darkred'], zorder=2.1)

patch99 = Patch(facecolor=c1)
patch95 = Patch(facecolor='tab:red')
patch68 = Patch(facecolor='darkred')
handles, labels = ax2.get_legend_handles_labels()
handles += [(patch68, patch95, patch99)]
labels += [r"$68\%,95\%,99\%$  C.L."]
ax2.legend(handles=handles, labels=labels, loc=(2.5, .5),
           handler_map={tuple: mpl.legend_handler.HandlerTuple(ndivide=None, pad=0.0)},
           frameon=False)

plt.tight_layout()
plt.subplots_adjust(wspace=0.0, hspace=0.0)
plt.show()
# Out:
# /var/folders/fv/1zh_rtgn403_j1sl_9fqmp9m0000gs/T/ipykernel_50243/3440821014.py:116: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()
